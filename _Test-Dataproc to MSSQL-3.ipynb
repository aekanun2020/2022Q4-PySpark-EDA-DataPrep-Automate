# %% [raw]
# Dataproc to MSSQL
# export NUMWORKERS=2
# export WORKER=n1-standard-8
# export MASTER=n1-standard-8
# gcloud dataproc clusters create aekanun-datascience-1 - zone asia-east1-a - master-machine-type=$MASTER - worker-machine-type=$WORKER - num-workers $NUMWORKERS - scopes cloud-platform - bucket 'oct22–23' - project bigdatainpractice1 - region asia-east1 - properties spark:spark.jars.packages=com.microsoft.azure:spark-mssql-connector:1.0.2 - properties spark:spark.driver.maxResultSize=50g - properties spark:spark.driver.memory=58g - properties spark:spark.executor-memory=1g - max-age 240m - image-version=1.4-ubuntu18 - enable-component-gateway - optional-components=JUPYTER,ANACONDA - properties 'spark:spark.yarn.executor.memoryOverhead = 8200' - properties dataproc:dataproc.conscrypt.provider.enable=false

# %%
server_name = "jdbc:sqlserver://34.72.0.181"
database_name = "TestDB"
url = server_name + ";" + "databaseName=" + database_name + ";"

table_name = "spark_loan_stat_10000"
username = "SA"
password = "Passw0rd123456" # Please specify password here

# %%
read_result_df = spark.read.format("jdbc")\
        .option("url", url) \
        .option("dbtable", table_name) \
        .option("user", username) \
        .option("password", password)\
        .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver").load()

# %%
read_result_df.columns
# Out:
# ['loan_amnt',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'loan_status',
#  'purpose',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'last_credit_pull_d']

# %%
read_result_df.head(10)
# Out:
# [Row(loan_amnt=10000, term=' 36 months', int_rate=6.99, installment=308.73, grade='A', emp_length='10+ years', home_ownership='MORTGAGE', annual_inc=350000.0, verification_status='Source Verified', loan_status='Fully Paid', purpose='debt_consolidation', addr_state='CT', dti='9.96', delinq_2yrs='0', earliest_cr_line='Aug', inq_last_6mths=1.0, open_acc=17, pub_rec=0, revol_bal=32605, revol_util=64.1, total_acc=32, last_credit_pull_d='Oct'),
#  Row(loan_amnt=16000, term=' 36 months', int_rate=13.49, installment=542.89, grade='C', emp_length='10+ years', home_ownership='MORTGAGE', annual_inc=101300.0, verification_status='Verified', loan_status='Fully Paid', purpose='debt_consolidation', addr_state='LA', dti='22.66', delinq_2yrs='0', earliest_cr_line='Sep', inq_last_6mths=0.0, open_acc=13, pub_rec=0, revol_bal=39957, revol_util=85.2, total_acc=25, last_credit_pull_d='Oct'),
#  Row(loan_amnt=1500, term=' 36 months', int_rate=15.99, installment=52.73, grade='C', emp_length='10+ years', home_ownership='RENT', annual_inc=76000.0, verification_status='Verified', loan_status='Fully Paid', purpose='moving', addr_state='CA', dti='31', delinq_2yrs='0', earliest_cr_line='May', inq_last_6mths=2.0, open_acc=8, pub_rec=0, revol_bal=24350, revol_util=90.5, total_acc=23, last_credit_pull_d='Mar'),
#  Row(loan_amnt=4000, term=' 36 months', int_rate=19.99, installment=148.64, grade='D', emp_length='10+ years', home_ownership='RENT', annual_inc=51000.0, verification_status='Source Verified', loan_status='Fully Paid', purpose='debt_consolidation', addr_state='OH', dti='24.61', delinq_2yrs='0', earliest_cr_line='Aug', inq_last_6mths=2.0, open_acc=14, pub_rec=1, revol_bal=8780, revol_util=62.3, total_acc=64, last_credit_pull_d='Oct'),
#  Row(loan_amnt=6000, term=' 36 months', int_rate=16.99, installment=213.89, grade='D', emp_length='10+ years', home_ownership='MORTGAGE', annual_inc=42000.0, verification_status='Source Verified', loan_status='Fully Paid', purpose='debt_consolidation', addr_state='NV', dti='12.89', delinq_2yrs='0', earliest_cr_line='Mar', inq_last_6mths=0.0, open_acc=10, pub_rec=0, revol_bal=7994, revol_util=38.8, total_acc=14, last_credit_pull_d='Feb'),
#  Row(loan_amnt=1200, term=' 36 months', int_rate=13.49, installment=40.72, grade='C', emp_length='7 years', home_ownership='MORTGAGE', annual_inc=39000.0, verification_status='Source Verified', loan_status='Fully Paid', purpose='debt_consolidation', addr_state='NY', dti='25.29', delinq_2yrs='0', earliest_cr_line='Jul', inq_last_6mths=1.0, open_acc=9, pub_rec=0, revol_bal=1880, revol_util=5.7, total_acc=15, last_credit_pull_d='Aug'),
#  Row(loan_amnt=21000, term=' 60 months', int_rate=11.44, installment=461.22, grade='B', emp_length='10+ years', home_ownership='MORTGAGE', annual_inc=114200.0, verification_status='Verified', loan_status='Fully Paid', purpose='debt_consolidation', addr_state='MA', dti='21.17', delinq_2yrs='0', earliest_cr_line='Mar', inq_last_6mths=0.0, open_acc=18, pub_rec=0, revol_bal=51998, revol_util=81.0, total_acc=47, last_credit_pull_d='Aug'),
#  Row(loan_amnt=5000, term=' 36 months', int_rate=21.49, installment=189.64, grade='D', emp_length='9 years', home_ownership='RENT', annual_inc=80000.0, verification_status='Verified', loan_status='Fully Paid', purpose='debt_consolidation', addr_state='CA', dti='9.13', delinq_2yrs='0', earliest_cr_line='Mar', inq_last_6mths=0.0, open_acc=16, pub_rec=0, revol_bal=11333, revol_util=29.2, total_acc=33, last_credit_pull_d='Oct'),
#  Row(loan_amnt=13500, term=' 60 months', int_rate=10.49, installment=290.11, grade='B', emp_length='10+ years', home_ownership='MORTGAGE', annual_inc=75000.0, verification_status='Not Verified', loan_status='Fully Paid', purpose='debt_consolidation', addr_state='AZ', dti='11.52', delinq_2yrs='0', earliest_cr_line='Nov', inq_last_6mths=1.0, open_acc=15, pub_rec=1, revol_bal=8129, revol_util=22.1, total_acc=34, last_credit_pull_d='Apr'),
#  Row(loan_amnt=14000, term=' 36 months', int_rate=18.99, installment=513.12, grade='D', emp_length='1 year', home_ownership='RENT', annual_inc=40000.0, verification_status='Source Verified', loan_status='Charged Off', purpose='debt_consolidation', addr_state='ME', dti='23.01', delinq_2yrs='1', earliest_cr_line='Dec', inq_last_6mths=0.0, open_acc=7, pub_rec=0, revol_bal=5280, revol_util=62.9, total_acc=9, last_credit_pull_d='Apr')]
